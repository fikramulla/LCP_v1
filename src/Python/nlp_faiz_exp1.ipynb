# %%
#try to redo what i did in R to see if it renders better
#have 3 prelim csvs created - index, orgs, and sdgs... need "content"
#03122022

# %%
# !pip install tabula
# !pip install PyPDF2
# !pip install pdfminer
# !pip install pdfminer.six
# Out:
# ...
#   Created wheel for tabula: filename=tabula-1.0.5-py3-none-any.whl size=10601 sha256=0d45a6c04cdf70a22a6be5de405ca8ec835488d75198da9d2b2b62dc16c5634f
#   Stored in directory: /root/.cache/pip/wheels/4b/f2/ad/7a426638f06a9829f8b0a097575b3d77fd651e9ef72ac7feb5
# Successfully built tabula
# ...

# %%
import tabula
import spacy
import PyPDF2
from pdfminer.high_level import extract_text
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/Colab Notebooks/nlp/pdf_source")

# %%
#!touch "/content/gdrive/My Drive/sample_file.txt"

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks/nlp/pdf_source'

# %% [markdown]
# #### load a pdf file

# %%
filename = "The-Sustainable-Development-Goals-Report-2021_English.pdf"

# %%
text = extract_text(filename)

# %%
type(text)
# Out:
# str

# %%
len(text)
# Out:
# 240109

# %% [markdown]
# #### alternate method 1, page by page attempt

# %%
# create a pdf file object
pdfFileObj = open(filename, 'rb')
 
# create a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
 
for i in range(pdfReader.numPages):
    pageObj = pdfReader.getPage(i)
    print(pageObj.extractText())
 
# closing the pdf file object
pdfFileObj.close()

# %% [markdown]
# #### alternate method 2

# %%
pdfFileObj = open(filename, 'rb')

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
pageObj = pdfReader.getPage(0)
page1 = pageObj.extractText()

# %%
page1
# Out:
# 'The Sustainable Development Goals Report\n2021\n'

# %%
dbn_df = pd.DataFrame([page1])

# %%
dbn_df
# Out:
#                                                    0
# 0   The Sustainable Development Goals Report\n2021\n
# 0  Contents\nForeword\n ............................

# %%
pageObj = pdfReader.getPage(1)
page2 = pageObj.extractText()

# %%
page2
# Out:
# 'Contents\nForeword\n ................................... 2View from the pandemic\n ..................... 3Investing in data\n............................. 4Overview\n ................................... 8Goal 1\n No poverty\n.................................. 26Goal 2\n Zero hunger\n................................. 28Goal 3\n Good health and well-being\n................... 30Goal 4\n Quality education\n............................ 34Goal 5\n Gender equality\n ............................. 36Goal 6\n Clean water and sanitation\n ................... 38Goal 7\n Affordable and clean energy\n.................. 40\nGoal 8\n Decent work and economic growth\n............ 42Goal 9\n Industry, innovation and infrastructure\n........ 44Goal 10\n Reduced inequalities\n......................... 46Goal 11\n Sustainable cities and communities\n ........... 48Goal 12\n Responsible consumption and production\n ..... 50Goal 13\n Climate action\n............................... 52Goal 14\n Life below 
# ...

# %%
dbn_df2 = pd.DataFrame([page2])

# %%
dbn_df = pd.concat([dbn_df, dbn_df2])
